# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Carlos Olivella**
#
# My desired occupation is Data Analyst or Data Scientist.

# %% [markdown]
# *I am interested in Data Science because I like the idea of obtaining insights from something that could otherwise be of little help. I like the idea of having a dataset with millions of rows (which a human cannot obtain insights from alone), processing, analyzing, and visualizing it, therefore obtaining meaningful information that can lead to change within an organization.*

# %% [markdown]
# ### The following code shows that multiplying a number by a specific percentage is equal to multiplying that percentage (in number form) by the initial number (in percentage form).

# %%
x = 7 * 0.25
y = 25 * 0.07

print(x)
print(y)
# Out:
# 1.75
# 1.7500000000000002

# %% [markdown]
# | This              | Table          | Includes |
# | ----------------- | -------------- | --------:|
# | ~~strikethrough~~ | `highlighting` | Money $1600 |
#
#
# 1. This
# 2. is
# 3. a
# 4. bulleted
# 5. list
#
# - This
# - is
# - an
# - unordered
# - list
